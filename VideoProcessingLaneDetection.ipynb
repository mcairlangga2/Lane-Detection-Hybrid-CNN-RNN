# %%
import cv2 
import numpy as np
import torch
import torch.nn as nn
from torchvision import models
import torch.nn.functional as F

# %% [markdown]
# Initiate Model

# %% [markdown]
# # SegNet

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import math
import numpy as np
from torch.autograd import Variable

class double_conv(nn.Module):
    '''(conv => BN => ReLU) * 2'''
    def __init__(self, in_ch, out_ch):
        super(double_conv, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, 3, padding=1),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_ch, out_ch, 3, padding=1),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        x = self.conv(x)
        return x


class inconv(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(inconv, self).__init__()
        self.conv = double_conv(in_ch, out_ch)

    def forward(self, x):
        x = self.conv(x)
        return x


class down(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(down, self).__init__()
        self.mpconv = nn.Sequential(
            nn.MaxPool2d(2),
            double_conv(in_ch, out_ch)
        )

    def forward(self, x):
        x = self.mpconv(x)
        return x


class up(nn.Module):
    def __init__(self, in_ch, out_ch, bilinear=True):
        super(up, self).__init__()

        #  would be a nice idea if the upsampling could be learned too,
        #  but my machine do not have enough memory to handle all those weights
        if bilinear:
            self.up = nn.UpsamplingBilinear2d(scale_factor=2)
        else:
            self.up = nn.ConvTranspose2d(in_ch//2, in_ch//2, 2, stride=2)

        self.conv = double_conv(in_ch, out_ch)

    def forward(self, x1, x2):
        x1 = self.up(x1)
        diffX = x1.size()[2] - x2.size()[2]
        diffY = x1.size()[3] - x2.size()[3]
        x2 = F.pad(x2, (diffX // 2, int(diffX / 2),
                        diffY // 2, int(diffY / 2)))
        x = torch.cat([x2, x1], dim=1)
        x = self.conv(x)
        return x


class outconv(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(outconv, self).__init__()
        self.conv = nn.Conv2d(in_ch, out_ch, 1)

    def forward(self, x):
        x = self.conv(x)
        return x


class ConvLSTMCell(nn.Module):

    def __init__(self, input_size, input_dim, hidden_dim, kernel_size, bias):
        """
        Initialize ConvLSTM cell.

        Parameters
        ----------
        input_size: (int, int)
            Height and width of input tensor as (height, width).
        input_dim: int
            Number of channels of input tensor.
        hidden_dim: int
            Number of channels of hidden state.
        kernel_size: (int, int)
            Size of the convolutional kernel.
        bias: bool
            Whether or not to add the bias.
        """

        super(ConvLSTMCell, self).__init__()

        self.height, self.width = input_size
        self.input_dim = input_dim
        self.hidden_dim = hidden_dim

        self.kernel_size = kernel_size
        self.padding = kernel_size[0] // 2, kernel_size[1] // 2
        self.bias = bias

        self.conv = nn.Conv2d(in_channels=self.input_dim + self.hidden_dim,
                              out_channels=4 * self.hidden_dim,
                              kernel_size=self.kernel_size,
                              padding=self.padding,
                              bias=self.bias)

    def forward(self, input_tensor, cur_state):
        h_cur, c_cur = cur_state

        combined = torch.cat([input_tensor, h_cur], dim=1)  # concatenate along channel axis

        combined_conv = self.conv(combined)

        cc_i, cc_f, cc_o, cc_g = torch.split(combined_conv, self.hidden_dim, dim=1)
        i = torch.sigmoid(cc_i)
        f = torch.sigmoid(cc_f)
        o = torch.sigmoid(cc_o)
        g = torch.tanh(cc_g)

        c_next = f * c_cur + i * g
        h_next = o * torch.tanh(c_next)

        return h_next, c_next

    def init_hidden(self, batch_size):
        return (torch.zeros(batch_size, self.hidden_dim, self.height, self.width).cuda(),
                torch.zeros(batch_size, self.hidden_dim, self.height, self.width).cuda())


class ConvLSTM(nn.Module):

    def __init__(self, input_size, input_dim, hidden_dim, kernel_size, num_layers,
                 batch_first=False, bias=True, return_all_layers=False):
        super(ConvLSTM, self).__init__()

        self._check_kernel_size_consistency(kernel_size)

        # Make sure that both `kernel_size` and `hidden_dim` are lists having len == num_layers
        kernel_size = self._extend_for_multilayer(kernel_size, num_layers)
        hidden_dim = self._extend_for_multilayer(hidden_dim, num_layers)
        if not len(kernel_size) == len(hidden_dim) == num_layers:
            raise ValueError('Inconsistent list length.')

        self.height, self.width = input_size

        self.input_dim = input_dim
        self.hidden_dim = hidden_dim
        self.kernel_size = kernel_size
        self.num_layers = num_layers
        self.batch_first = batch_first
        self.bias = bias
        self.return_all_layers = return_all_layers

        cell_list = []
        for i in range(0, self.num_layers):
            cur_input_dim = self.input_dim if i == 0 else self.hidden_dim[i - 1]

            cell_list.append(ConvLSTMCell(input_size=(self.height, self.width),
                                          input_dim=cur_input_dim,
                                          hidden_dim=self.hidden_dim[i],
                                          kernel_size=self.kernel_size[i],
                                          bias=self.bias))

        self.cell_list = nn.ModuleList(cell_list)

    def forward(self, input_tensor, hidden_state=None):
        """

        Parameters
        ----------
        input_tensor: todo
            5-D Tensor either of shape (t, b, c, h, w) or (b, t, c, h, w)
        hidden_state: todo
            None. todo implement stateful

        Returns
        -------
        last_state_list, layer_output
        """
        if not self.batch_first:
            # (t, b, c, h, w) -> (b, t, c, h, w)
            input_tensor=input_tensor.permute(1, 0, 2, 3, 4)

        # Implement stateful ConvLSTM
        if hidden_state is not None:
            raise NotImplementedError()
        else:
            hidden_state = self._init_hidden(batch_size=input_tensor.size(0))

        layer_output_list = []
        last_state_list = []

        seq_len = input_tensor.size(1)
        cur_layer_input = input_tensor

        for layer_idx in range(self.num_layers):

            h, c = hidden_state[layer_idx]
            output_inner = []
            for t in range(seq_len):
                h, c = self.cell_list[layer_idx](input_tensor=cur_layer_input[:, t, :, :, :],
                                                 cur_state=[h, c])


                output_inner.append(h)

            layer_output = torch.stack(output_inner, dim=1)
            cur_layer_input = layer_output

            layer_output = layer_output.permute(1, 0, 2, 3, 4)

            layer_output_list.append(layer_output)
            last_state_list.append([h, c])

        if not self.return_all_layers:
            layer_output_list = layer_output_list[-1:]
            last_state_list = last_state_list[-1:]

        return layer_output_list, last_state_list

    def _init_hidden(self, batch_size):
        init_states = []
        for i in range(self.num_layers):
            init_states.append(self.cell_list[i].init_hidden(batch_size))
        return init_states

    @staticmethod
    def _check_kernel_size_consistency(kernel_size):
        if not (isinstance(kernel_size, tuple) or
                (isinstance(kernel_size, list) and all([isinstance(elem, tuple) for elem in kernel_size]))):
            raise ValueError('`kernel_size` must be tuple or list of tuples')

    @staticmethod
    def _extend_for_multilayer(param, num_layers):
        if not isinstance(param, list):
            param = [param] * num_layers
        return param

# %%
import torch
import torch.nn as nn
from torchvision import models
import torch.nn.functional as F

class SegNet_ConvLSTM(nn.Module):
    def __init__(self):
        super(SegNet_ConvLSTM,self).__init__()
        self.vgg16_bn = models.vgg16_bn(pretrained=True).features
        self.relu = nn.ReLU(inplace=True)
        self.index_MaxPool = nn.MaxPool2d(kernel_size=2, stride=2,return_indices=True)
        self.index_UnPool = nn.MaxUnpool2d(kernel_size=2, stride=2)
        # net struct
        self.conv1_block = nn.Sequential(self.vgg16_bn[0],  # conv2d(3,64,(3,3))
                                         self.vgg16_bn[1],  # bn(64,eps=1e-05,momentum=0.1,affine=True)
                                         self.vgg16_bn[2],  # relu(in_place)
                                         self.vgg16_bn[3],  # conv2d(3,64,(3,3))
                                         self.vgg16_bn[4],  # bn(64,eps=1e-05,momentum=0.1,affine=True)
                                         self.vgg16_bn[5]   # relu(in_place)
                                         )
        self.conv2_block = nn.Sequential(self.vgg16_bn[7],
                                         self.vgg16_bn[8],
                                         self.vgg16_bn[9],
                                         self.vgg16_bn[10],
                                         self.vgg16_bn[11],
                                         self.vgg16_bn[12]
                                         )
        self.conv3_block = nn.Sequential(self.vgg16_bn[14],
                                         self.vgg16_bn[15],
                                         self.vgg16_bn[16],
                                         self.vgg16_bn[17],
                                         self.vgg16_bn[18],
                                         self.vgg16_bn[19],
                                         self.vgg16_bn[20],
                                         self.vgg16_bn[21],
                                         self.vgg16_bn[22]
                                         )
        self.conv4_block = nn.Sequential(self.vgg16_bn[24],
                                         self.vgg16_bn[25],
                                         self.vgg16_bn[26],
                                         self.vgg16_bn[27],
                                         self.vgg16_bn[28],
                                         self.vgg16_bn[29],
                                         self.vgg16_bn[30],
                                         self.vgg16_bn[31],
                                         self.vgg16_bn[32]
                                         )
        self.conv5_block = nn.Sequential(self.vgg16_bn[34],
                                         self.vgg16_bn[35],
                                         self.vgg16_bn[36],
                                         self.vgg16_bn[37],
                                         self.vgg16_bn[38],
                                         self.vgg16_bn[39],
                                         self.vgg16_bn[40],
                                         self.vgg16_bn[41],
                                         self.vgg16_bn[42]
                                         )

        self.upconv5_block = nn.Sequential(
                                           nn.Conv2d(512, 512, kernel_size=(3, 3), padding=(1,1)),
                                           nn.BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True),
                                           self.relu,
                                           nn.Conv2d(512, 512, kernel_size=(3, 3), padding=(1,1)),
                                           nn.BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True),
                                           self.relu,
                                           nn.Conv2d(512, 512, kernel_size=(3, 3), padding=(1, 1)),
                                           nn.BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True),
                                           self.relu,
                                           )
        self.upconv4_block = nn.Sequential(
                                           nn.Conv2d(512, 512, kernel_size=(3, 3), padding=(1,1)),
                                           nn.BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True),
                                           self.relu,
                                           nn.Conv2d(512, 512, kernel_size=(3, 3), padding=(1,1)),
                                           nn.BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True),
                                           self.relu,
                                           nn.Conv2d(512, 256, kernel_size=(3, 3), padding=(1, 1)),
                                           nn.BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True),
                                           self.relu,
                                           )
        self.upconv3_block = nn.Sequential(
                                           nn.Conv2d(256, 256, kernel_size=(3, 3), padding=(1,1)),
                                           nn.BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True),
                                           self.relu,
                                           nn.Conv2d(256, 256, kernel_size=(3, 3), padding=(1,1)),
                                           nn.BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True),
                                           self.relu,
                                           nn.Conv2d(256, 128, kernel_size=(3, 3), padding=(1, 1)),
                                           nn.BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True),
                                           self.relu,
                                           )
        self.upconv2_block = nn.Sequential(
                                           nn.Conv2d(128, 128, kernel_size=(3, 3), padding=(1,1)),
                                           nn.BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True),
                                           self.relu,
                                           nn.Conv2d(128, 64, kernel_size=(3, 3), padding=(1,1)),
                                           nn.BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True),
                                           self.relu
                                           )
        self.upconv1_block = nn.Sequential(
                                           nn.Conv2d(64, 64, kernel_size=(3, 3), padding=(1,1)),
                                           nn.BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True),
                                           self.relu,
                                           nn.Conv2d(64, 2, kernel_size=(3, 3), padding=(1,1)),
                                           )
        self.convlstm = ConvLSTM(input_size=(4,8),
                                 input_dim=512,
                                 hidden_dim=[512, 512],
                                 kernel_size=(3,3),
                                 num_layers=2,
                                 batch_first=False,
                                 bias=True,
                                 return_all_layers=False)
    def forward(self, x):
        x = torch.unbind(x, dim=1)
        data = []
        for item in x:
            f1, idx1 = self.index_MaxPool(self.conv1_block(item))
            f2, idx2 = self.index_MaxPool(self.conv2_block(f1))
            f3, idx3 = self.index_MaxPool(self.conv3_block(f2))
            f4, idx4 = self.index_MaxPool(self.conv4_block(f3))
            f5, idx5 = self.index_MaxPool(self.conv5_block(f4))
            data.append(f5.unsqueeze(0))
        data = torch.cat(data, dim=0)
        lstm, _ = self.convlstm(data)
        test = lstm[0][-1,:,:,:,:]
        up6 = self.index_UnPool(test,idx5)
        up5 = self.index_UnPool(self.upconv5_block(up6), idx4)
        up4 = self.index_UnPool(self.upconv4_block(up5), idx3)
        up3 = self.index_UnPool(self.upconv3_block(up4), idx2)
        up2 = self.index_UnPool(self.upconv2_block(up3), idx1)
        up1 = self.upconv1_block(up2)
        return F.log_softmax(up1, dim=1)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
path = '/content/drive/MyDrive/Colab Notebooks/ModelNN/weights_best.pth'
model = SegNet().to(device)
model.load_state_dict(torch.load(path))
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16_bn-6c64b313.pth" to /root/.cache/torch/hub/checkpoints/vgg16_bn-6c64b313.pth
#   0%|          | 0.00/528M [00:00<?, ?B/s]
# <All keys matched successfully>

# %% [markdown]
# # UNet

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import math
import numpy as np
from torch.autograd import Variable

class double_conv(nn.Module):
    '''(conv => BN => ReLU) * 2'''
    def __init__(self, in_ch, out_ch):
        super(double_conv, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, 3, padding=1),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_ch, out_ch, 3, padding=1),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        x = self.conv(x)
        return x


class inconv(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(inconv, self).__init__()
        self.conv = double_conv(in_ch, out_ch)

    def forward(self, x):
        x = self.conv(x)
        return x


class down(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(down, self).__init__()
        self.mpconv = nn.Sequential(
            nn.MaxPool2d(2),
            double_conv(in_ch, out_ch)
        )

    def forward(self, x):
        x = self.mpconv(x)
        return x


class up(nn.Module):
    def __init__(self, in_ch, out_ch, bilinear=True):
        super(up, self).__init__()

        #  would be a nice idea if the upsampling could be learned too,
        #  but my machine do not have enough memory to handle all those weights
        if bilinear:
            self.up = nn.UpsamplingBilinear2d(scale_factor=2)
        else:
            self.up = nn.ConvTranspose2d(in_ch//2, in_ch//2, 2, stride=2)

        self.conv = double_conv(in_ch, out_ch)

    def forward(self, x1, x2):
        x1 = self.up(x1)
        diffX = x1.size()[2] - x2.size()[2]
        diffY = x1.size()[3] - x2.size()[3]
        x2 = F.pad(x2, (diffX // 2, int(diffX / 2),
                        diffY // 2, int(diffY / 2)))
        x = torch.cat([x2, x1], dim=1)
        x = self.conv(x)
        return x


class outconv(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(outconv, self).__init__()
        self.conv = nn.Conv2d(in_ch, out_ch, 1)

    def forward(self, x):
        x = self.conv(x)
        return x


class ConvLSTMCell(nn.Module):

    def __init__(self, input_size, input_dim, hidden_dim, kernel_size, bias):
        """
        Initialize ConvLSTM cell.

        Parameters
        ----------
        input_size: (int, int)
            Height and width of input tensor as (height, width).
        input_dim: int
            Number of channels of input tensor.
        hidden_dim: int
            Number of channels of hidden state.
        kernel_size: (int, int)
            Size of the convolutional kernel.
        bias: bool
            Whether or not to add the bias.
        """

        super(ConvLSTMCell, self).__init__()

        self.height, self.width = input_size
        self.input_dim = input_dim
        self.hidden_dim = hidden_dim

        self.kernel_size = kernel_size
        self.padding = kernel_size[0] // 2, kernel_size[1] // 2
        self.bias = bias

        self.conv = nn.Conv2d(in_channels=self.input_dim + self.hidden_dim,
                              out_channels=4 * self.hidden_dim,
                              kernel_size=self.kernel_size,
                              padding=self.padding,
                              bias=self.bias)

    def forward(self, input_tensor, cur_state):
        h_cur, c_cur = cur_state

        combined = torch.cat([input_tensor, h_cur], dim=1)  # concatenate along channel axis

        combined_conv = self.conv(combined)

        cc_i, cc_f, cc_o, cc_g = torch.split(combined_conv, self.hidden_dim, dim=1)
        i = torch.sigmoid(cc_i)
        f = torch.sigmoid(cc_f)
        o = torch.sigmoid(cc_o)
        g = torch.tanh(cc_g)

        c_next = f * c_cur + i * g
        h_next = o * torch.tanh(c_next)

        return h_next, c_next

    def init_hidden(self, batch_size):
        return (torch.zeros(batch_size, self.hidden_dim, self.height, self.width).cuda(),
                torch.zeros(batch_size, self.hidden_dim, self.height, self.width).cuda())


class ConvLSTM(nn.Module):

    def __init__(self, input_size, input_dim, hidden_dim, kernel_size, num_layers,
                 batch_first=False, bias=True, return_all_layers=False):
        super(ConvLSTM, self).__init__()

        self._check_kernel_size_consistency(kernel_size)

        # Make sure that both `kernel_size` and `hidden_dim` are lists having len == num_layers
        kernel_size = self._extend_for_multilayer(kernel_size, num_layers)
        hidden_dim = self._extend_for_multilayer(hidden_dim, num_layers)
        if not len(kernel_size) == len(hidden_dim) == num_layers:
            raise ValueError('Inconsistent list length.')

        self.height, self.width = input_size

        self.input_dim = input_dim
        self.hidden_dim = hidden_dim
        self.kernel_size = kernel_size
        self.num_layers = num_layers
        self.batch_first = batch_first
        self.bias = bias
        self.return_all_layers = return_all_layers

        cell_list = []
        for i in range(0, self.num_layers):
            cur_input_dim = self.input_dim if i == 0 else self.hidden_dim[i - 1]

            cell_list.append(ConvLSTMCell(input_size=(self.height, self.width),
                                          input_dim=cur_input_dim,
                                          hidden_dim=self.hidden_dim[i],
                                          kernel_size=self.kernel_size[i],
                                          bias=self.bias))

        self.cell_list = nn.ModuleList(cell_list)

    def forward(self, input_tensor, hidden_state=None):
        """

        Parameters
        ----------
        input_tensor: todo
            5-D Tensor either of shape (t, b, c, h, w) or (b, t, c, h, w)
        hidden_state: todo
            None. todo implement stateful

        Returns
        -------
        last_state_list, layer_output
        """
        if not self.batch_first:
            # (t, b, c, h, w) -> (b, t, c, h, w)
            input_tensor=input_tensor.permute(1, 0, 2, 3, 4)

        # Implement stateful ConvLSTM
        if hidden_state is not None:
            raise NotImplementedError()
        else:
            hidden_state = self._init_hidden(batch_size=input_tensor.size(0))

        layer_output_list = []
        last_state_list = []

        seq_len = input_tensor.size(1)
        cur_layer_input = input_tensor

        for layer_idx in range(self.num_layers):

            h, c = hidden_state[layer_idx]
            output_inner = []
            for t in range(seq_len):
                h, c = self.cell_list[layer_idx](input_tensor=cur_layer_input[:, t, :, :, :],
                                                 cur_state=[h, c])


                output_inner.append(h)

            layer_output = torch.stack(output_inner, dim=1)
            cur_layer_input = layer_output

            layer_output = layer_output.permute(1, 0, 2, 3, 4)

            layer_output_list.append(layer_output)
            last_state_list.append([h, c])

        if not self.return_all_layers:
            layer_output_list = layer_output_list[-1:]
            last_state_list = last_state_list[-1:]

        return layer_output_list, last_state_list

    def _init_hidden(self, batch_size):
        init_states = []
        for i in range(self.num_layers):
            init_states.append(self.cell_list[i].init_hidden(batch_size))
        return init_states

    @staticmethod
    def _check_kernel_size_consistency(kernel_size):
        if not (isinstance(kernel_size, tuple) or
                (isinstance(kernel_size, list) and all([isinstance(elem, tuple) for elem in kernel_size]))):
            raise ValueError('`kernel_size` must be tuple or list of tuples')

    @staticmethod
    def _extend_for_multilayer(param, num_layers):
        if not isinstance(param, list):
            param = [param] * num_layers
        return param

# %%
class UNet_ConvLSTM(nn.Module):
    def __init__(self, n_channels, n_classes):
        super(UNet_ConvLSTM, self).__init__()
        self.inc = inconv(n_channels, 64)
        self.down1 = down(64, 128)
        self.down2 = down(128, 256)
        self.down3 = down(256, 512)
        self.down4 = down(512, 512)
        self.up1 = up(1024, 256)
        self.up2 = up(512, 128)
        self.up3 = up(256, 64)
        self.up4 = up(128, 64)
        self.outc = outconv(64, n_classes)
        self.convlstm = ConvLSTM(input_size=(8,16),
                                 input_dim=512,
                                 hidden_dim=[512, 512],
                                 kernel_size=(3,3),
                                 num_layers=2,
                                 batch_first=False,
                                 bias=True,
                                 return_all_layers=False)

    def forward(self, x):
        x = torch.unbind(x, dim=1)
        data = []
        for item in x:
            x1 = self.inc(item)
            x2 = self.down1(x1)
            x3 = self.down2(x2)
            x4 = self.down3(x3)
            x5 = self.down4(x4)
            data.append(x5.unsqueeze(0))
        data = torch.cat(data, dim=0)
        lstm, _ = self.convlstm(data)
        test = lstm[0][ -1,:, :, :, :]
        x = self.up1(test, x4)
        x = self.up2(x, x3)
        x = self.up3(x, x2)
        x = self.up4(x, x1)
        x = self.outc(x)
        return x, test

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
path = '/content/drive/MyDrive/TA_UNetLSTM/weights_best.pth'
model = UNet_ConvLSTM(3,2).to(device)
model.load_state_dict(torch.load(path))
# Out:
# <All keys matched successfully>

# %%
class UNet(nn.Module):
    def __init__(self, n_channels, n_classes):
        super(UNet, self).__init__()
        self.inc = inconv(n_channels, 64)
        self.down1 = down(64, 128)
        self.down2 = down(128, 256)
        self.down3 = down(256, 512)
        self.down4 = down(512, 512)
        self.up1 = up(1024, 256)
        self.up2 = up(512, 128)
        self.up3 = up(256, 64)
        self.up4 = up(128, 64)
        self.outc = outconv(64, n_classes)

    def forward(self, x):
        x1 = self.inc(x)
        x2 = self.down1(x1)
        x3 = self.down2(x2)
        x4 = self.down3(x3)
        x5 = self.down4(x4)
        x = self.up1(x5, x4)
        x = self.up2(x, x3)
        x = self.up3(x, x2)
        x = self.up4(x, x1)
        x = self.outc(x)
        return x

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
path = '/content/drive/MyDrive/Colab Notebooks/ModelNN/UNet/weights_best.pth'
model = UNet(3,2).to(device)
model.load_state_dict(torch.load(path))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e8ebced5a8cb> in <module>()
#       1 device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
#       2 path = '/content/drive/MyDrive/Colab Notebooks/ModelNN/UNet/weights_best.pth'
# ----> 3 model = UNet(3,2).to(device)
#       4 model.load_state_dict(torch.load(path))
#
# NameError: name 'UNet' is not defined

# %% [markdown]
# # Listing file

# %%
import os
def getListOfFiles(dirName):
  listOfFile = os.listdir(dirName)
  allFiles = list()
  for item in listOfFile:
    fullPath = os.path.join(dirName,item)
    if os.path.isdir(fullPath):
      allFiles = allFiles + getListOfFiles(fullPath)
    else:
      allFiles.append(fullPath)
  return allFiles

def getList(dirName):
    
    
    
    # Get the list of all files in directory tree at given path
    listOfFiles = getListOfFiles(dirName)
    
    # Print the files
    #for elem in listOfFiles:
        #print(elem)
    #print ("****************")
    
    # Get the list of all files in directory tree at given path
    listOfFiles = list()
    for (dirpath, dirnames, filenames) in os.walk(dirName):
        listOfFiles += [os.path.join(dirpath, file) for file in filenames]
        
        
    # Print the files    
    #for elem in listOfFiles:
        #print(elem)  
    return listOfFiles

# %% [markdown]
# # Extraxting Frame and Inference

# %% [markdown]
# ## cnn-rnn

# %%
import cv2 
import os
from torchvision import transforms
import torchvision
from PIL import Image
convert_tensor = transforms.ToTensor()
cap = cv2.VideoCapture('/content/drive/MyDrive/Video Processing/cerahlurus.mp4')
try: 
  if not os.path.exists('/content/drive/MyDrive/Video Processing/cerahlurusTA_2'):
    os.makedirs('/content/drive/MyDrive/Video Processing/cerahlurusTA_2')
except OSError: 
  print('Error: Creating directory of data')

currentframe = 1
while(True):
  success,frame = cap.read()
  if success:
    path = '/content/drive/MyDrive/Video Processing/cerahlurusTA_2/'
    name = path + 'frame' + str(currentframe) +'.jpg'
    pred_name = path + 'pred' + str(currentframe) + '.jpg'
    print('creating...'+name)

    with torch.no_grad():
      if currentframe % 5 == 0: 
        model.eval()
        frame = cv2.resize(frame,(256,128))
        cv2.imwrite(name, frame)
        list_image = getList(path)
        #print(list_image)
        data = []
        data1 = torch.unsqueeze(convert_tensor(Image.open(list_image[-5])),0)
        data.append(data1)
        data2 = torch.unsqueeze(convert_tensor(Image.open(list_image[-4])),0)
        data.append(data2)
        data3 = torch.unsqueeze(convert_tensor(Image.open(list_image[-3])),0)
        data.append(data3)
        data4 = torch.unsqueeze(convert_tensor(Image.open(list_image[-2])),0)
        data.append(data4)
        data5 = torch.unsqueeze(convert_tensor(Image.open(list_image[-1])),0)
        data.append(data5)
        
        data = torch.cat(data,0).unsqueeze(0).to(device)
        #print(data)
        pred,_ = model(data)
        pred = pred.max(1,keepdim=True)[1].type(torch.Tensor)
        torchvision.utils.save_image(pred,pred_name)
      
      frame = cv2.resize(frame,(256,128))
      cv2.imwrite(name, frame)
      currentframe +=1
  else:
    break

cap.release()
cv2.destroyAllWindows()
# Out:
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame1.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame2.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame3.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame4.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame5.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame6.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame7.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame8.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame9.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame10.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame11.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame12.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame13.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame14.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame15.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame16.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame17.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame18.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame19.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame20.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame21.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame22.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame23.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame24.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame25.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame26.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame27.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame28.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame29.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame30.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame31.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame32.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame33.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame34.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame35.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame36.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame37.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame38.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame39.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame40.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame41.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame42.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame43.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame44.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame45.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame46.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame47.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame48.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame49.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame50.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame51.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame52.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame53.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame54.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame55.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame56.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame57.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame58.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame59.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame60.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame61.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame62.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame63.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame64.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame65.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame66.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame67.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame68.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame69.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame70.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame71.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame72.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame73.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame74.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame75.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame76.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame77.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame78.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame79.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame80.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame81.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame82.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame83.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame84.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame85.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame86.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame87.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame88.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame89.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame90.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame91.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame92.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame93.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame94.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame95.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame96.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame97.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame98.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame99.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame100.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame101.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame102.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame103.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame104.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame105.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame106.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame107.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame108.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame109.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame110.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame111.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame112.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame113.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame114.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame115.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame116.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame117.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame118.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame119.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame120.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame121.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame122.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame123.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame124.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame125.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame126.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame127.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame128.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame129.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame130.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame131.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame132.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame133.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame134.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame135.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame136.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame137.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame138.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame139.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame140.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame141.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame142.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame143.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame144.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame145.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame146.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame147.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame148.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame149.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame150.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame151.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame152.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame153.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame154.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame155.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame156.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame157.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame158.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame159.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame160.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame161.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame162.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame163.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame164.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame165.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame166.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame167.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame168.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame169.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame170.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame171.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame172.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame173.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame174.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame175.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame176.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame177.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame178.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame179.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame180.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame181.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame182.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame183.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame184.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame185.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame186.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame187.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame188.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame189.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame190.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame191.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame192.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame193.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame194.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame195.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame196.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame197.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame198.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame199.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame200.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame201.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame202.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame203.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame204.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame205.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame206.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame207.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame208.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame209.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame210.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame211.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame212.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame213.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame214.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame215.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame216.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame217.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame218.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame219.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame220.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame221.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame222.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame223.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame224.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame225.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame226.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame227.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame228.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame229.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame230.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame231.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame232.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame233.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame234.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame235.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame236.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame237.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame238.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame239.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame240.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame241.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame242.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame243.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame244.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame245.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame246.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame247.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame248.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame249.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame250.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame251.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame252.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame253.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame254.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame255.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame256.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame257.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame258.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame259.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame260.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame261.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame262.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame263.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame264.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame265.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame266.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame267.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame268.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame269.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame270.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame271.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame272.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame273.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame274.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame275.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame276.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame277.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame278.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame279.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame280.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame281.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame282.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame283.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame284.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame285.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame286.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame287.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame288.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame289.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame290.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame291.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame292.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame293.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame294.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame295.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame296.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame297.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame298.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame299.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame300.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame301.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame302.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame303.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame304.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame305.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame306.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame307.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame308.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame309.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame310.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame311.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame312.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame313.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame314.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame315.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame316.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame317.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame318.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame319.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame320.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame321.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame322.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame323.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame324.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame325.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame326.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame327.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame328.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame329.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame330.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame331.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame332.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame333.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame334.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame335.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame336.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame337.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame338.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame339.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame340.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame341.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame342.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame343.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame344.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame345.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame346.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame347.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame348.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame349.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame350.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame351.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame352.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame353.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame354.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame355.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame356.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame357.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame358.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame359.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame360.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame361.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame362.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame363.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame364.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame365.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame366.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame367.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame368.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame369.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame370.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame371.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame372.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame373.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame374.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame375.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame376.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame377.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame378.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame379.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame380.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame381.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame382.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame383.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame384.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame385.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame386.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame387.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame388.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame389.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame390.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame391.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame392.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame393.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame394.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame395.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame396.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame397.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame398.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame399.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame400.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame401.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame402.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame403.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame404.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame405.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame406.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame407.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame408.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame409.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame410.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame411.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame412.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame413.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame414.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame415.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame416.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame417.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame418.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame419.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame420.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame421.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame422.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame423.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame424.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame425.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame426.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame427.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame428.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame429.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame430.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame431.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame432.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame433.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame434.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame435.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame436.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame437.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame438.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame439.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame440.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame441.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame442.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame443.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame444.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame445.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame446.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame447.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame448.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame449.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame450.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame451.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame452.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame453.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame454.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame455.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame456.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame457.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame458.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame459.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame460.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame461.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame462.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame463.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame464.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame465.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame466.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame467.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame468.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame469.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame470.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame471.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame472.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame473.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame474.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame475.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame476.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame477.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame478.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame479.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame480.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame481.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame482.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame483.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame484.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame485.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame486.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame487.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame488.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame489.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame490.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame491.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame492.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame493.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame494.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame495.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame496.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame497.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame498.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame499.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame500.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame501.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame502.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame503.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame504.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame505.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame506.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame507.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame508.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame509.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame510.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame511.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame512.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame513.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame514.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame515.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame516.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame517.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame518.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame519.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame520.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame521.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame522.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame523.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame524.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame525.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame526.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame527.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame528.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame529.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame530.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame531.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame532.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame533.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame534.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame535.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame536.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame537.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame538.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame539.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame540.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame541.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame542.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame543.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame544.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame545.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame546.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame547.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame548.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame549.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame550.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame551.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame552.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame553.jpg
# creating.../content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame554.jpg

# %% [markdown]
# # cnn

# %%
import cv2 
import os
from torchvision import transforms
import torchvision
convert_tensor = transforms.ToTensor()
video_path = '/content/drive/MyDrive/Video Processing/VID_20220323_170619.mp4'
cap = cv2.VideoCapture(video_path)
try: 
  if not os.path.exists('/content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet'):
    os.makedirs('/content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet')
except OSError: 
  print('Error: Creating directory of data')

currentframe = 0
while(True):
  success,frame = cap.read()
  if success:
    path = '/content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/'
    name = path + 'frame' + str(currentframe) +'.jpg'
    #pred_name = path + 'pred' + str(currentframe) + '.jpg'
    print('creating...'+name)

    with torch.no_grad():
      frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
      frame_resized = cv2.resize(frame,(256,128))
      frame = cv2.resize(frame,(256,128))
      cv2.imwrite(name, frame)
      frame = convert_tensor(frame).unsqueeze(0).to(device)
      frame = model(frame).type(torch.Tensor).to(device)
      frame = frame.max(1,keepdim=True)[1].type(torch.FloatTensor)
      torchvision.utils.save_image(frame,name)
      #frame = frame.numpy()

    
      #frame = cv2.imread(name)
      #frame[:,:,1] = 0
      #frame[:,:,0] = 0
      #added_image = cv2.addWeighted(frame_resized,1,frame,1,1)
      #combined = cv2.imwrite(name, added_image)
    currentframe +=1
  else:
    break

cap.release()
cv2.destroyAllWindows()
# Out:
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame0.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame1.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame2.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame4.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame5.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame6.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame7.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame8.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame9.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame10.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame11.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame12.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame13.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame14.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame15.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame16.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame17.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame18.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame19.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame20.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame21.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame22.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame23.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame24.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame25.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame26.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame27.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame28.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame29.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame30.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame31.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame32.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame33.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame34.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame35.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame36.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame37.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame38.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame39.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame40.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame41.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame42.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame43.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame44.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame45.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame46.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame47.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame48.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame49.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame50.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame51.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame52.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame53.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame54.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame55.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame56.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame57.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame58.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame59.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame60.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame61.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame62.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame63.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame64.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame65.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame66.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame67.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame68.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame69.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame70.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame71.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame72.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame73.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame74.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame75.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame76.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame77.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame78.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame79.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame80.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame81.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame82.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame83.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame84.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame85.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame86.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame87.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame88.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame89.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame90.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame91.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame92.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame93.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame94.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame95.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame96.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame97.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame98.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame99.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame100.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame101.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame102.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame103.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame104.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame105.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame106.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame107.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame108.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame109.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame110.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame111.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame112.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame113.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame114.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame115.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame116.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame117.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame118.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame119.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame120.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame121.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame122.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame123.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame124.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame125.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame126.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame127.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame128.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame129.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame130.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame131.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame132.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame133.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame134.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame135.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame136.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame137.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame138.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame139.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame140.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame141.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame142.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame143.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame144.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame145.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame146.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame147.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame148.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame149.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame150.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame151.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame152.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame153.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame154.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame155.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame156.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame157.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame158.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame159.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame160.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame161.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame162.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame163.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame164.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame165.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame166.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame167.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame168.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame169.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame170.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame171.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame172.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame173.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame174.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame175.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame176.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame177.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame178.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame179.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame180.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame181.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame182.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame183.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame184.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame185.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame186.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame187.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame188.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame189.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame190.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame191.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame192.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame193.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame194.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame195.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame196.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame197.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame198.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame199.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame200.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame201.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame202.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame203.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame204.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame205.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame206.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame207.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame208.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame209.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame210.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame211.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame212.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame213.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame214.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame215.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame216.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame217.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame218.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame219.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame220.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame221.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame222.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame223.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame224.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame225.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame226.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame227.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame228.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame229.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame230.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame231.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame232.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame233.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame234.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame235.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame236.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame237.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame238.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame239.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame240.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame241.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame242.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame243.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame244.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame245.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame246.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame247.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame248.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame249.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame250.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame251.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame252.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame253.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame254.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame255.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame256.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame257.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame258.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame259.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame260.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame261.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame262.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame263.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame264.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame265.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame266.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame267.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame268.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame269.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame270.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame271.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame272.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame273.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame274.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame275.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame276.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame277.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame278.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame279.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame280.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame281.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame282.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame283.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame284.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame285.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame286.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame287.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame288.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame289.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame290.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame291.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame292.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame293.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame294.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame295.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame296.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame297.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame298.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame299.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame300.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame301.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame302.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame303.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame304.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame305.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame306.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame307.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame308.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame309.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame310.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame311.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame312.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame313.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame314.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame315.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame316.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame317.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame318.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame319.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame320.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame321.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame322.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame323.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame324.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame325.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame326.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame327.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame328.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame329.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame330.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame331.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame332.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame333.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame334.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame335.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame336.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame337.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame338.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame339.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame340.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame341.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame342.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame343.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame344.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame345.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame346.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame347.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame348.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame349.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame350.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame351.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame352.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame353.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame354.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame355.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame356.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame357.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame358.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame359.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame360.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame361.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame362.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame363.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame364.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame365.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame366.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame367.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame368.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame369.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame370.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame371.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame372.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame373.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame374.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame375.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame376.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame377.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame378.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame379.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame380.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame381.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame382.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame383.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame384.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame385.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame386.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame387.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame388.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame389.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame390.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame391.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame392.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame393.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame394.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame395.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame396.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame397.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame398.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame399.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame400.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame401.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame402.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame403.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame404.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame405.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame406.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame407.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame408.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame409.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame410.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame411.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame412.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame413.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame414.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame415.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame416.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame417.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame418.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame419.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame420.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame421.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame422.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame423.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame424.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame425.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame426.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame427.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame428.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame429.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame430.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame431.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame432.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame433.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame434.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame435.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame436.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame437.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame438.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame439.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame440.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame441.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame442.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame443.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame444.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame445.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame446.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame447.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame448.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame449.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame450.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame451.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame452.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame453.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame454.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame455.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame456.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame457.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame458.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame459.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame460.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame461.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame462.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame463.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame464.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame465.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame466.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame467.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame468.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame469.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame470.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame471.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame472.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame473.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame474.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame475.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame476.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame477.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame478.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame479.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame480.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame481.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame482.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame483.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame484.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame485.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame486.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame487.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame488.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame489.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame490.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame491.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame492.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame493.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame494.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame495.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame496.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame497.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame498.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame499.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame500.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame501.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame502.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame503.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame504.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame505.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame506.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame507.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame508.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame509.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame510.jpg
# ...
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3827.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3828.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3829.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3830.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3831.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3832.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3833.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3834.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3835.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3836.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3837.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3838.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3839.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3840.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3841.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3842.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3843.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3844.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3845.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3846.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3847.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3848.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3849.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3850.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3851.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3852.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3853.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3854.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3855.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3856.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3857.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3858.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3859.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3860.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3861.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3862.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3863.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3864.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3865.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3866.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3867.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3868.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3869.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3870.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3871.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3872.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3873.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3874.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3875.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3876.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3877.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3878.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3879.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3880.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3881.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3882.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3883.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3884.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3885.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3886.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3887.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3888.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3889.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3890.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3891.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3892.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3893.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3894.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3895.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3896.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3897.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3898.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3899.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3900.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3901.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3902.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3903.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3904.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3905.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3906.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3907.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3908.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3909.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3910.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3911.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3912.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3913.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3914.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3915.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3916.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3917.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3918.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3919.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3920.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3921.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3922.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3923.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3924.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3925.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3926.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3927.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3928.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3929.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3930.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3931.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3932.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3933.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3934.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3935.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3936.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3937.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3938.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3939.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3940.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3941.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3942.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3943.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3944.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3945.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3946.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3947.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3948.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3949.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3950.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3951.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3952.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3953.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3954.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3955.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3956.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3957.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3958.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3959.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3960.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3961.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3962.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3963.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3964.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3965.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3966.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3967.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3968.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3969.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3970.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3971.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3972.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3973.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3974.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3975.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3976.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3977.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3978.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3979.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3980.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3981.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3982.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3983.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3984.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3985.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3986.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3987.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3988.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3989.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3990.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3991.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3992.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3993.jpg
# creating.../content/drive/MyDrive/Video Processing/outVID_20220323_170619_SegNet/frame3994.jpg

# %% [markdown]
# # Making Video

# %%
import numpy as np
import glob
import cv2
 
img_array = []
for filename in glob.glob('/content/drive/MyDrive/Video Processing/pred3/*.jpg'):
    img = cv2.imread(filename)
    height, width, layers = img.shape
    size = (width,height)
    img_array.append(img)
 
 
out = cv2.VideoWriter('pred3_mask.avi',cv2.VideoWriter_fourcc(*'DIVX'), 20, size)
 
for i in range(len(img_array)):
    out.write(img_array[i])
out.release()

# %%
# !pip install natsort
# Out:
# Collecting natsort
#   Downloading natsort-8.1.0-py3-none-any.whl (37 kB)
# Installing collected packages: natsort
# Successfully installed natsort-8.1.0

# %%
import natsort

# %%
from natsort import os_sorted

# %% [markdown]
# # Gabungin frame ke hasil prediksi

# %%
import os
def getListNatsort(dir):
    lst1 = os.listdir(dir)
    lst1 = os_sorted(lst1) 
    i = 0
    lst_dir = []
    for i in range(len(lst1)):
        filename = dir + lst1[i]
        lst_dir.append(filename)
    return lst_dir

# %%
path_image = '/content/drive/MyDrive/Video Processing/cerahlurusTA_2/'
path_pred = '/content/drive/MyDrive/Video Processing/cerahlurusTA_2_UNetLSTM/'
path_result = '/content/drive/MyDrive/Video Processing/cerahlurusTA_2_UNetLSTM_result/'
list_image = getListNatsort(path_image)
list_pred = getListNatsort(path_pred)
len(list_image)
list_image[9]
#list_pred[0]
# Out:
# '/content/drive/MyDrive/Video Processing/cerahlurusTA_2/frame10.jpg'

# %% [markdown]
# # Overlay Image every 6 images:
# #### --> : overlay
# ### list_image[0] --> list_pred[0]
# ### list_image[1] --> list_pred[0]
# ### list_image[2] --> list_pred[0]
# ### list_image[3] --> list_pred[0]
# ### list_image[4] --> list_pred[0]
# ### list_image[5] --> list_pred[0]
# ### list_image[6] --> list_pred[1]
# ### list_image[7] --> list_pred[1]

# %%
import cv2
current_pred = 0 

for i in range(len(ordered)+1):
  if i == 0:
    name = path_result + 'frame' + str(i) +'.jpg'
    img = cv2.imread(ordered[i])
    mask = cv2.imread(ordered_pred[current_pred])
    mask[:,:,1] = 0
    mask[:,:,0] = 0
    added_image = cv2.addWeighted(img,1,mask,0.5,1)
    combined = cv2.imwrite(name,added_image)
  if i % 6 == 0 and i != 0  :
    img = cv2.imread(ordered[i])
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    mask = cv2.imread(ordered_pred[current_pred])
    mask[:,:,1] = 0
    mask[:,:,0] = 0
    added_image = cv2.addWeighted(img,1,mask,1,1)
    combined = cv2.imwrite(name,added_image)
    current_pred +=1
  name = path_result + 'frame' + str(i) +'.jpg'
  print(name)
  img = cv2.imread(ordered[i])
  img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  if i == 2888:
    break
  mask = cv2.imread(ordered_pred[current_pred])
  mask[:,:,1] = 0
  mask[:,:,0] = 0
  added_image = cv2.addWeighted(img,1,mask,0.5,1)
  combined = cv2.imwrite(name,added_image)
# Out:
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame0.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame1.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame3.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame4.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame5.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame6.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame7.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame8.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame9.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame10.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame11.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame12.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame13.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame14.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame15.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame16.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame17.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame18.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame19.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame20.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame21.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame22.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame23.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame24.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame25.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame26.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame27.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame28.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame29.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame30.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame31.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame32.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame33.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame34.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame35.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame36.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame37.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame38.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame39.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame40.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame41.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame42.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame43.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame44.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame45.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame46.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame47.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame48.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame49.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame50.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame51.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame52.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame53.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame54.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame55.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame56.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame57.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame58.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame59.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame60.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame61.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame62.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame63.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame64.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame65.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame66.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame67.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame68.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame69.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame70.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame71.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame72.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame73.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame74.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame75.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame76.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame77.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame78.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame79.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame80.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame81.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame82.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame83.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame84.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame85.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame86.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame87.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame88.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame89.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame90.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame91.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame92.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame93.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame94.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame95.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame96.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame97.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame98.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame99.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame100.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame101.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame102.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame103.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame104.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame105.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame106.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame107.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame108.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame109.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame110.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame111.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame112.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame113.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame114.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame115.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame116.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame117.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame118.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame119.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame120.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame121.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame122.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame123.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame124.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame125.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame126.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame127.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame128.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame129.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame130.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame131.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame132.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame133.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame134.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame135.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame136.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame137.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame138.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame139.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame140.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame141.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame142.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame143.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame144.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame145.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame146.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame147.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame148.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame149.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame150.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame151.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame152.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame153.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame154.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame155.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame156.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame157.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame158.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame159.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame160.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame161.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame162.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame163.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame164.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame165.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame166.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame167.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame168.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame169.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame170.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame171.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame172.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame173.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame174.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame175.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame176.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame177.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame178.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame179.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame180.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame181.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame182.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame183.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame184.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame185.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame186.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame187.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame188.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame189.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame190.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame191.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame192.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame193.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame194.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame195.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame196.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame197.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame198.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame199.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame200.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame201.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame202.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame203.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame204.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame205.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame206.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame207.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame208.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame209.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame210.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame211.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame212.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame213.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame214.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame215.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame216.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame217.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame218.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame219.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame220.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame221.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame222.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame223.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame224.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame225.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame226.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame227.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame228.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame229.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame230.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame231.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame232.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame233.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame234.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame235.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame236.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame237.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame238.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame239.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame240.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame241.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame242.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame243.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame244.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame245.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame246.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame247.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame248.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame249.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame250.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame251.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame252.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame253.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame254.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame255.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame256.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame257.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame258.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame259.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame260.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame261.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame262.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame263.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame264.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame265.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame266.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame267.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame268.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame269.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame270.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame271.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame272.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame273.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame274.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame275.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame276.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame277.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame278.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame279.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame280.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame281.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame282.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame283.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame284.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame285.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame286.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame287.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame288.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame289.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame290.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame291.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame292.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame293.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame294.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame295.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame296.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame297.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame298.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame299.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame300.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame301.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame302.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame303.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame304.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame305.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame306.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame307.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame308.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame309.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame310.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame311.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame312.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame313.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame314.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame315.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame316.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame317.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame318.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame319.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame320.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame321.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame322.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame323.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame324.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame325.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame326.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame327.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame328.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame329.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame330.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame331.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame332.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame333.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame334.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame335.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame336.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame337.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame338.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame339.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame340.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame341.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame342.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame343.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame344.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame345.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame346.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame347.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame348.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame349.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame350.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame351.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame352.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame353.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame354.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame355.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame356.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame357.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame358.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame359.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame360.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame361.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame362.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame363.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame364.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame365.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame366.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame367.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame368.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame369.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame370.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame371.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame372.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame373.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame374.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame375.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame376.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame377.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame378.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame379.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame380.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame381.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame382.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame383.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame384.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame385.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame386.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame387.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame388.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame389.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame390.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame391.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame392.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame393.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame394.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame395.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame396.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame397.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame398.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame399.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame400.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame401.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame402.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame403.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame404.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame405.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame406.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame407.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame408.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame409.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame410.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame411.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame412.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame413.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame414.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame415.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame416.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame417.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame418.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame419.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame420.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame421.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame422.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame423.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame424.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame425.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame426.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame427.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame428.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame429.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame430.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame431.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame432.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame433.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame434.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame435.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame436.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame437.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame438.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame439.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame440.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame441.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame442.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame443.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame444.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame445.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame446.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame447.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame448.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame449.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame450.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame451.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame452.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame453.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame454.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame455.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame456.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame457.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame458.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame459.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame460.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame461.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame462.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame463.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame464.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame465.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame466.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame467.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame468.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame469.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame470.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame471.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame472.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame473.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame474.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame475.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame476.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame477.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame478.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame479.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame480.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame481.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame482.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame483.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame484.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame485.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame486.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame487.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame488.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame489.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame490.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame491.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame492.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame493.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame494.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame495.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame496.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame497.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame498.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame499.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame500.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame501.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame502.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame503.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame504.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame505.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame506.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame507.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame508.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame509.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame510.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame511.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame512.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame513.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame514.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame515.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame516.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame517.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame518.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame519.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame520.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame521.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame522.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame523.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame524.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame525.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame526.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame527.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame528.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame529.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame530.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame531.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame532.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame533.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame534.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame535.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame536.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame537.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame538.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame539.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame540.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame541.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame542.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame543.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame544.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame545.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame546.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame547.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame548.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame549.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame550.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame551.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame552.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame553.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame554.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame555.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame556.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame557.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame558.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame559.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame560.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame561.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame562.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame563.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame564.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame565.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame566.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame567.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame568.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame569.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame570.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame571.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame572.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame573.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame574.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame575.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame576.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame577.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame578.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame579.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame580.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame581.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame582.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame583.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame584.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame585.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame586.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame587.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame588.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame589.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame590.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame591.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame592.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame593.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame594.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame595.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame596.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame597.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame598.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame599.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame600.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame601.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame602.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame603.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame604.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame605.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame606.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame607.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame608.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame609.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame610.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame611.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame612.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame613.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame614.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame615.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame616.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame617.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame618.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame619.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame620.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame621.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame622.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame623.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame624.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame625.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame626.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame627.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame628.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame629.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame630.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame631.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame632.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame633.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame634.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame635.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame636.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame637.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame638.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame639.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame640.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame641.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame642.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame643.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame644.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame645.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame646.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame647.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame648.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame649.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame650.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame651.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame652.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame653.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame654.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame655.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame656.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame657.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame658.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame659.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame660.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame661.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame662.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame663.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame664.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame665.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame666.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame667.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame668.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame669.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame670.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame671.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame672.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame673.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame674.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame675.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame676.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame677.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame678.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame679.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame680.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame681.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame682.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame683.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame684.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame685.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame686.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame687.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame688.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame689.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame690.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame691.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame692.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame693.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame694.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame695.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame696.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame697.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame698.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame699.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame700.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame701.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame702.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame703.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame704.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame705.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame706.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame707.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame708.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame709.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame710.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame711.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame712.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame713.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame714.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame715.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame716.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame717.jpg
# ...
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2658.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2659.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2660.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2661.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2662.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2663.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2664.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2665.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2666.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2667.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2668.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2669.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2670.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2671.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2672.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2673.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2674.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2675.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2676.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2677.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2678.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2679.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2680.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2681.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2682.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2683.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2684.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2685.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2686.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2687.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2688.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2689.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2690.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2691.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2692.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2693.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2694.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2695.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2696.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2697.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2698.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2699.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2700.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2701.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2702.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2703.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2704.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2705.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2706.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2707.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2708.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2709.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2710.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2711.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2712.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2713.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2714.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2715.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2716.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2717.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2718.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2719.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2720.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2721.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2722.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2723.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2724.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2725.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2726.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2727.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2728.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2729.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2730.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2731.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2732.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2733.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2734.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2735.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2736.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2737.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2738.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2739.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2740.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2741.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2742.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2743.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2744.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2745.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2746.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2747.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2748.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2749.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2750.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2751.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2752.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2753.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2754.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2755.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2756.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2757.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2758.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2759.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2760.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2761.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2762.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2763.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2764.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2765.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2766.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2767.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2768.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2769.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2770.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2771.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2772.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2773.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2774.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2775.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2776.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2777.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2778.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2779.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2780.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2781.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2782.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2783.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2784.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2785.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2786.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2787.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2788.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2789.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2790.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2791.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2792.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2793.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2794.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2795.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2796.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2797.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2798.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2799.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2800.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2801.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2802.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2803.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2804.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2805.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2806.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2807.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2808.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2809.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2810.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2811.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2812.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2813.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2814.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2815.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2816.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2817.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2818.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2819.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2820.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2821.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2822.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2823.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2824.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2825.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2826.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2827.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2828.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2829.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2830.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2831.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2832.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2833.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2834.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2835.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2836.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2837.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2838.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2839.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2840.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2841.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2842.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2843.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2844.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2845.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2846.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2847.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2848.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2849.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2850.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2851.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2852.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2853.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2854.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2855.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2856.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2857.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2858.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2859.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2860.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2861.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2862.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2863.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2864.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2865.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2866.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2867.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2868.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2869.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2870.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2871.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2872.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2873.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2874.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2875.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2876.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2877.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2878.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2879.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2880.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2881.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2882.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2883.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2884.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2885.jpg
# /content/drive/MyDrive/Video Processing/overlay_pred3/frame2886.jpg
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-74-14e1f9efb307> in <module>()
#      26   if i == 2888:
#      27     break
# ---> 28   mask = cv2.imread(ordered_pred[current_pred])
#      29   mask[:,:,1] = 0
#      30   mask[:,:,0] = 0
#
# IndexError: list index out of range

# %%
import cv2
current_mask = 0
#current_frame = 0
for i in range(5, (len(list_image)+1)):
  if i in range((len(list_image)-5), (len(list_image))):
    name = path_result + 'frame' + str(i) +'.jpg'
    img = cv2.imread(list_image[i-1])
    mask = cv2.imread(list_pred[current_mask-1])
    mask[:,:,1] = 0
    mask[:,:,0] = 0
    added_image = cv2.addWeighted(img,1,mask,0.5,1)
    combined = cv2.imwrite(name,added_image)
  if i % 5 == 0:
    current_mask += 1
  

  name = path_result + 'frame' + str(i) +'.jpg'
  img = cv2.imread(list_image[i-1])
  mask = cv2.imread(list_pred[current_mask])
  mask[:,:,1] = 0
  mask[:,:,0] = 0
  added_image = cv2.addWeighted(img,1,mask,0.5,1)
  combined = cv2.imwrite(name,added_image)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-33-5cd5ad97b69b> in <module>()
#      17   name = path_result + 'frame' + str(i) +'.jpg'
#      18   img = cv2.imread(list_image[i-1])
# ---> 19   mask = cv2.imread(list_pred[current_mask])
#      20   mask[:,:,1] = 0
#      21   mask[:,:,0] = 0
#
# IndexError: list index out of range

# %%
range((len(list_image)-4),len(list_image))
# Out:
# range(550, 554)

# %% [markdown]
# # Make Video from Frames

# %%
import numpy as np
import cv2
 
img_array = []
for filename in getListNatsort('/content/drive/MyDrive/Video Processing/cerahlurusTA_2_UNetLSTM_result/'):
    img = cv2.imread(filename)
    height, width, layers = img.shape
    size = (width,height)
    img_array.append(img)
 
 
out = cv2.VideoWriter('cerahlurusUNetLSTMResult.mp4',cv2.VideoWriter_fourcc(*'DIVX'), 30, size)
 
for i in range(len(img_array)):
    out.write(img_array[i])
out.release()
